# %% [markdown]
# <a href="https://colab.research.google.com/github/naitoyuma3230/python-anlysis/blob/master/covid_age_anlysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 東京コロナ感染者情報を使用した年代別人数推移のグラフ作成

# %% [markdown]
# ## データの取得
#
# [東京都オープンデータカタログ](https://www.youtube.com/watch?v=9XEX4mZFOhA&t=16058s)から東京都 新型コロナウイルス感染症新規陽性者数についてのCSVデータをダウウンロード
#
# データをJupyterで読み込み出力

# %%
import pandas as pd
df = pd.read_csv('/content/covid-tokyo-data/130001_tokyo_covid19_patients_9e4b6290e76826a41c5e34ac575ec04f.csv')
df
# Out:
#             No  全国地方公共団体コード 都道府県名  市区町村名      公表_年月日      発症_年月日      確定_年月日  \
# 0            1       130001   東京都    NaN  2020-01-24         NaN         NaN
# 1            2       130001   東京都    NaN  2020-01-25         NaN         NaN
# 2            3       130001   東京都    NaN  2020-01-30         NaN         NaN
# 3            4       130001   東京都    NaN  2020-02-13         NaN         NaN
# 4            5       130001   東京都    NaN  2020-02-14         NaN         NaN
# ...        ...          ...   ...    ...         ...         ...         ...
# 171138  170282       130001   東京都    NaN  2021-06-25         NaN  2021-06-24
# 171139  170283       130001   東京都    NaN  2021-06-25  2021-06-22  2021-06-25
# 171140  170284       130001   東京都    NaN  2021-06-25  2021-06-19  2021-06-24
# 171141  170285       130001   東京都    NaN  2021-06-25  2021-06-22  2021-06-24
# 171142  170286       130001   東京都    NaN        2021         NaN         NaN
#
# ...

# %% [markdown]
# 171143 件 × 17 項目
#
# データの欠損確認
# 数値は欠損した値の数を表す

# %% [markdown]
# ## データの加工

# %%
df.isnull().sum()
# Out:
# No                   0
# 全国地方公共団体コード          0
# 都道府県名                0
# 市区町村名           171143
# 公表_年月日               0
# 発症_年月日           75948
# 確定_年月日           25733
# 患者_居住地               1
# 患者_年代                1
# 患者_性別                1
# 患者_職業            25734
# 患者_状態           171143
# 患者_症状           171143
# 患者_渡航歴の有無フラグ    171143
# 患者_接触歴の有無フラグ    111155
# 備考              171143
# 退院済フラグ               1
# dtype: int64

# %% [markdown]
# 年代ごとの人数を算出する

# %%
df['患者_年代'].value_counts()
# Out:
# 20代       45502
# 30代       32554
# 40代       26320
# 50代       21798
# 60代       11675
# 70代        9535
# 10代        9449
# 80代        6955
# 10歳未満      4748
# 90代        2487
# 100歳以上      108
# 不明            6
# -             5
# Name: 患者_年代, dtype: int64

# %% [markdown]
# groupメソッドを使用し「公表年月日」ごと、また「年代」ごとをグループとみなし人数を算出する。

# %%
df_groupby = df.groupby(['公表_年月日', '患者_年代']).count()
df_groupby
# Out:
#                   No  全国地方公共団体コード  都道府県名  市区町村名  発症_年月日  確定_年月日  患者_居住地  \
# 公表_年月日     患者_年代
# 2020-01-24 40代     1            1      1      0       0       0       1
# 2020-01-25 30代     1            1      1      0       0       0       1
# 2020-01-30 30代     1            1      1      0       0       0       1
# 2020-02-13 70代     1            1      1      0       0       0       1
# 2020-02-14 50代     1            1      1      0       0       0       1
# ...               ..          ...    ...    ...     ...     ...     ...
# 2021-06-25 40代    26           26     26      0      22      26      26
#            50代    26           26     26      0      20      26      26
#            60代     7            7      7      0       5       7       7
#            70代     4            4      4      0       3       4       4
#            80代     2            2      2      0       2       2       2
#
#                   患者_性別  患者_職業  患者_状態  患者_症状  患者_渡航歴の有無フラグ  患者_接触歴の有無フラグ  備考  \
# ...

# %% [markdown]
# ## グラフ化

# %% [markdown]
# 視覚化しやすいように番号を振りなおす
# また必要な項目のみ取り出す(Noは人数)

# %%
df_groupby = df_groupby.reset_index()[['公表_年月日', '患者_年代', 'No']]
df_groupby
# Out:
#           公表_年月日 患者_年代  No
# 0     2020-01-24   40代   1
# 1     2020-01-25   30代   1
# 2     2020-01-30   30代   1
# 3     2020-02-13   70代   1
# 4     2020-02-14   50代   1
# ...          ...   ...  ..
# 4431  2021-06-25   40代  26
# 4432  2021-06-25   50代  26
# 4433  2021-06-25   60代   7
# 4434  2021-06-25   70代   4
# 4435  2021-06-25   80代   2
#
# [4436 rows x 3 columns]

# %% [markdown]
# X軸に公表年月日、Y軸に人数を指定し、年代グループごとに色分けしてプロットする

# %%
import plotly.express as px

fig = px.line(df_groupby, x='公表_年月日', y='No', color='患者_年代')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Jupiter上では選択した年代の表示、非表示の切り替えが可能
